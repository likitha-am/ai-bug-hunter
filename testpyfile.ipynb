# %%
from agents.orchestrator import Orchestrator
from utils.logger import setup_logger

def main():
    logger = setup_logger()
    logger.info("🚀 Starting AI Bug Hunter...")

    try:
        orchestrator = Orchestrator()
        orchestrator.run_all()
        logger.success("✅ Bug hunting process completed successfully!")
    except Exception as e:
        logger.error(f"❌ Error during bug hunting: {e}")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from agents.orchestrator import Orchestrator
#       2 from utils.logger import setup_logger
#       4 def main():
#
# ImportError: cannot import name 'Orchestrator' from 'agents.orchestrator' (C:\Users\amlik\ai-bug-hunter\agents\orchestrator.py)
